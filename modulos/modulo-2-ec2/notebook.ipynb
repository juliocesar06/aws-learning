# %% [markdown]
# # Passo a Passo uso pratico ec2
# 1. Conectar na instância via SSH
#
#     - chmod 400 nome_da_sua_chave.pem
#     - ssh -i "nome_da_sua_chave.pem" ubuntu@<IP-PÚBLICO-DA-EC2>
#
#
# 2. Instalar Python e Flask
#
#     - sudo apt update -y && sudo apt upgrade -y
#
# 3. Criar um app Flask simples
#     - mkdir flask_app && cd flask_app
#     - nano app.py
#
#  * codigo
# 4. Abrir a porta no Security Group
#
#     - Volte para o console AWS → EC2 → Instâncias → Security → Security Groups
#     - ➡️ Edite as Inbound Rules (Regras de entrada):
#
#     - Type: Custom TCP
#
#     - Port range: 5000
#
#     - Source: 0.0.0.0/0 (ou apenas seu IP se quiser segurança extra)
#
# 5. Rodar o app e acessar pelo navegador
#     - python3 app.py

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return "Olá, mundo! 🚀 Flask rodando na EC2!"

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
